# %% [markdown]
# <a href="https://colab.research.google.com/github/RedBatProject/Data-Science/blob/main/work_75_student_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mealpy;
import mealpy
from mealpy.bio_based import BBO, EOA, IWO, SBO, SMA, TPO, VCS, WHO
from mealpy.evolutionary_based import CRO, DE, EP, ES, FPA, GA, MA
from mealpy.human_based import BRO, BSO, CA, CHIO, FBIO, GSKA, ICA, LCO, QSA, SARO, SSDO, TLO
from mealpy.math_based import AOA, CGO, GBO, HC, SCA, PSS
from mealpy.music_based import HS
from mealpy.physics_based import ArchOA, ASO, EFO, EO, HGSO, MVO, NRO, SA, TWO, WDO
# from mealpy.probabilistic_based import CEM
from mealpy.system_based import AEO, GCO, WCA
from mealpy.swarm_based import ABC, ACOR, ALO, AO, BA, BeesA, BES, BFO, BSA, COA, CSA, CSO, DO, EHO, FA, FFA, FOA, GOA, GWO, HGS
from mealpy.swarm_based import HHO, JA, MFO, MRFO, MSA, NMRA, PFA, PSO, SFO, SHO, SLO, SRSR, SSA, SSO, SSpiderA, SSpiderO, WOA
from sys import exit
import numpy as np
import tweepy
import webbrowser
import time
import pandas as pd
import datetime
import threading
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import cross_val_score
# !pip install mealpy
import mealpy
# Load libraries
# %tensorflow_version 2.x
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib

# import tensorflow.compat.v2.feature_column as fc

# import tensorflow as tf
from pandas.plotting import scatter_matrix
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import random as rn
# from sklearn.metrics import confusion_matrix, plot_confusion_matrix, classification_report
# create the models
from sklearn.tree import DecisionTreeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
# module imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import random as rn

# model imports
from sklearn.cluster import KMeans #one with clusterimg (disaster)
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.multiclass import OneVsRestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.dummy import DummyClassifier #that zero
from sklearn.svm import SVC, SVR
from sklearn.naive_bayes import GaussianNB
# from sklearn.ensemble import RandomForestClassifier
# processing imports
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import confusion_matrix
from time import time
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
# !pip install catboost
from xgboost import XGBClassifier
# from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn import metrics
# Sklearn modules & classes
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn import datasets, metrics
from mealpy.bio_based import SMA
import mealpy
from sklearn.naive_bayes import GaussianNB
import time
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
# !pip install catboost;
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor,GradientBoostingRegressor,HistGradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import LinearSVC
from sklearn import metrics
# Sklearn modules & classes
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn import datasets, metrics
from mealpy.bio_based import SMA
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,confusion_matrix
print("WELLCOME TO IMPLEMENTATION")
# create the models
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
# Out:
# Requirement already satisfied: mealpy in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.10/dist-packages (from mealpy) (1.25.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from mealpy) (3.7.1)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mealpy) (1.11.4)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from mealpy) (2.0.3)
# Requirement already satisfied: opfunu>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from mealpy) (1.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (2.8.2)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.10/dist-packages (from opfunu>=1.0.0->mealpy) (2.31.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->mealpy) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->mealpy) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->mealpy) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2024.2.2)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# WELLCOME TO IMPLEMENTATION

# %%
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Kaggle Data

# %%
# !mkdir ~/.kaggle
! cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d devansodariya/student-performance-data
# Out:
# Downloading student-performance-data.zip to /content
#   0% 0.00/7.16k [00:00<?, ?B/s]
# 100% 7.16k/7.16k [00:00<00:00, 10.6MB/s]

# %%
# !kaggle datasets download -d michaelchalamet/brain-cancer-data

# %%
# !unzip /content/student-performance-data.zip
# Out:
# Archive:  /content/student-performance-data.zip
#   inflating: student_data.csv

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv('/content/student_data.csv')
# lab = pd.read_csv('/content/drive/MyDrive/work75student/labels.csv')

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
# data['label'] = list(lab['final'])

# %%
# !rm -r -f /content/drive

# %%
# data['final'] = data['G1']+data['G2']+data['G3'])

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
import os
path = '/content/drive/MyDrive/work75student/'
os.makedirs(path,exist_ok=True)

# %%
# data.drop(data.columns[0],inplace=True,axis=1)

# %% [markdown]
# # VISUALIZE

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
data.sort_values(by='G3')
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 296     GP   F   19       U     GT3       T     4     4    health     other
# 144     GP   M   17       U     GT3       T     2     1     other     other
# 168     GP   F   16       U     GT3       T     2     2     other     other
# 333     GP   F   18       U     LE3       T     2     2     other     other
# 332     GP   F   18       U     GT3       T     3     3  services  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 286     GP   F   18       U     GT3       T     2     2   at_home   at_home
# 110     GP   M   15       U     LE3       A     4     4   teacher   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 113     GP   M   15       U     LE3       T     4     2   teacher     other
# 47      GP   M   16       U     GT3       T     4     3    health  services
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 296  ...      2        3      4     2     3      2        0  10   9   0
# 144  ...      5        4      5     1     2      5        0   5   0   0
# 168  ...      5        1      5     1     1      4        0   6   7   0
# 333  ...      4        3      3     1     1      2        0   8   8   0
# 332  ...      5        3      4     1     1      4        0   7   0   0
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 286  ...      4        3      3     1     2      2        5  18  18  19
# 110  ...      5        5      3     1     1      4        6  18  19  19
# 8    ...      4        2      2     1     1      1        0  16  18  19
# 113  ...      3        5      2     1     1      3       10  18  19  19
# 47   ...      4        2      2     1     1      2        4  19  19  20
#
# [395 rows x 33 columns]

# %%
g = data[data.columns[-1]].sort_values().copy()

# %%
# g = list(g)

# %%
# from collections import Counter

# %%
# u = Counter(g)

# %%
# u

# %%
plt.figure(figsize=(11,6))
g.value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.title('Grade Distribution')
plt.savefig(f'{path}labels.png',bbox_inches='tight')
g.to_csv(f'{path}labels.csv',index=False)

# %%
plt.figure(figsize=(10,8))
g.value_counts().plot(kind='pie', autopct='%.0f%%')
plt.title('Grade proportion (%)')
plt.legend()
plt.savefig(f'{path}labels.png',bbox_inches='tight')
g.to_csv(f'{path}labels.csv',index=False)

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %%
clc = data.columns

# %%
data.columns[:-3]
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences'],
#       dtype='object')

# %%
for i in ['school', 'sex', 'address', 'famsize', 'Pstatus',
       'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'goout']:
    data[i] = data[i].factorize()[0]

# %%
data
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        0        0        0     4     4     0     0  ...
# 1         0    0   17        0        0        1     1     1     0     1  ...
# 2         0    0   15        0        1        1     1     1     0     1  ...
# 3         0    0   15        0        0        1     4     2     1     2  ...
# 4         0    0   16        0        0        1     3     3     2     1  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        0        1        0     2     2     3     2  ...
# 391       1    1   17        0        1        1     3     1     3     2  ...
# 392       1    1   21        1        0        1     1     1     2     1  ...
# 393       1    1   18        1        1        1     3     2     3     1  ...
# 394       1    1   19        0        1        1     1     1     2     4  ...
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0         4         3      0     1     1       3         6   5   6   6
# 1         5         3      1     1     1       3         4   5   5   6
# 2         4         3      2     2     3       3        10   7   8  10
# 3         3         2      2     1     1       5         2  15  14  15
# 4         4         3      2     1     2       5         4   6  10  10
# ..      ...       ...    ...   ...   ...     ...       ...  ..  ..  ..
# 390       5         5      0     4     5       4        11   9   9   9
# 391       2         4      4     3     4       2         3  14  16  16
# 392       5         5      1     3     3       3         3  10   8   7
# 393       4         4      3     3     4       5         0  11  12  10
# 394       3         2      1     3     3       5         5   8   9   9
#
# [395 rows x 33 columns]

# %%
clc
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
x = clc[-2]
y = clc[-3]
hu = clc[-1]
sns.catplot(data=data, x=x, y=y,hue=hu)
plt.savefig(f'{path}relation_{x}_{y}_.png',bbox_inches='tight')
data[[x,y,hu]].to_csv(f'{path}relation_{x}_{y}_.csv')

# %%
# g = data.corr()
# sns.heatmap(g)
# plt.savefig(f'{path}heatmap.png',bbox_inches='tight')
# g.to_csv(f'{path}heatmap.csv')

# %% [markdown]
# # TRAINING

# %%
# data

# %%
data.rename(columns={data.columns[-1]: 'labels'}, inplace=True)

# %% [markdown]
# ### PCA

# %%
import numpy as np
from sklearn.decomposition import PCA
X = data.drop('labels',axis=1).to_numpy()
pca = PCA(n_components=10)
pca.fit(X)
# print(pca.explained_variance_ratio_)
l = pca.explained_variance_ratio_
# print(pca.singular_values_)
Y = pca.transform(X)

# %%
l.sum()
# Out:
# 0.8181701163043739

# %%
l[0:20].sum()
# Out:
# 0.8181701163043739

# %%
# X.columns = [f'{i}' for i in range(X.shape[1]-1)]+['labels']

# %%
# X.drop('labels',axis=1,inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    Y, data2['labels'], test_size=0.25, random_state=42)
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((4191, 10), (4191,), (1398, 10), (1398,))

# %%
x1,y1,x2,y2 = X_train, y_train, X_test, y_test

# %%
models = [HistGradientBoostingClassifier,XGBClassifier,RandomForestClassifier,DecisionTreeClassifier]
len(models)
# Out:
# 4

# %%
for model in models:
    try:
        clf = model(random_state=8)
    except:
        clf = model()


    clf.fit(x1,y1)
    y2_ = clf.predict(x2)
    print(f1_score(y2, y2_,average='macro'))
# Out:
# 0.8429549360617061
# 0.8462349345666675
# 0.849771155071771
# 0.7687577853246321

# %% [markdown]
# ### resume

# %%
for i in data.columns:
    data[i] = data[i].factorize()[0]

# %%
data['labels'].std()
# Out:
# 4.5814426109978434

# %%
data['labels'] = (data['labels']-data['labels'].mean())/data['labels'].std()

# %%
data['labels'] = g

# %%
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        0        0        0     4     4     0     0  ...
# 1         0    0   17        0        0        1     1     1     0     1  ...
# 2         0    0   15        0        1        1     1     1     0     1  ...
# 3         0    0   15        0        0        1     4     2     1     2  ...
# 4         0    0   16        0        0        1     3     3     2     1  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        0        1        0     2     2     3     2  ...
# 391       1    1   17        0        1        1     3     1     3     2  ...
# 392       1    1   21        1        0        1     1     1     2     1  ...
# 393       1    1   18        1        1        1     3     2     3     1  ...
# 394       1    1   19        0        1        1     1     1     2     4  ...
#
#      famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  labels
# 0         4         3      0     1     1       3         6   5   6       6
# 1         5         3      1     1     1       3         4   5   5       6
# 2         4         3      2     2     3       3        10   7   8      10
# 3         3         2      2     1     1       5         2  15  14      15
# 4         4         3      2     1     2       5         4   6  10      10
# ..      ...       ...    ...   ...   ...     ...       ...  ..  ..     ...
# 390       5         5      0     4     5       4        11   9   9       9
# 391       2         4      4     3     4       2         3  14  16      16
# 392       5         5      1     3     3       3         3  10   8       7
# 393       4         4      3     3     4       5         0  11  12      10
# 394       3         2      1     3     3       5         5   8   9       9
#
# [395 rows x 33 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data.drop('labels',axis=1), data['labels'], test_size=0.3, random_state=40)
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((276, 32), (276,), (119, 32), (119,))

# %%
x1,y1,x2,y2 = X_train, y_train, X_test, y_test

# %%
models = [
    # XGBRegressor
        #   ,CatBoostRegressor
        #   ,RandomForestRegressor
    # ,ExtraTreesRegressor
        #   ,GradientBoostingRegressor
        #   ,
    HistGradientBoostingRegressor
    # ,AdaBoostRegressor
    ]
len(models)
# Out:
# 1

# %%
from sklearn.metrics import *
# brier_score_loss,jaccard_score,class_likelihood_ratios,hinge_loss,roc_auc_score,hamming_loss,multilabel_confusion_matrix,roc_auc_score,zero_one_loss

# %%
import sklearn

# %%
dir(sklearn.metrics)
# Out:
# ['ConfusionMatrixDisplay',
#  'DetCurveDisplay',
#  'DistanceMetric',
#  'PrecisionRecallDisplay',
#  'PredictionErrorDisplay',
#  'RocCurveDisplay',
#  'SCORERS',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_base',
#  '_classification',
#  '_dist_metrics',
#  '_pairwise_distances_reduction',
#  '_pairwise_fast',
#  '_plot',
#  '_ranking',
#  '_regression',
#  '_scorer',
#  'accuracy_score',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'auc',
#  'average_precision_score',
#  'balanced_accuracy_score',
#  'brier_score_loss',
#  'calinski_harabasz_score',
#  'check_scoring',
#  'class_likelihood_ratios',
#  'classification_report',
#  'cluster',
#  'cohen_kappa_score',
#  'completeness_score',
#  'confusion_matrix',
#  'consensus_score',
#  'coverage_error',
#  'd2_absolute_error_score',
#  'd2_pinball_score',
#  'd2_tweedie_score',
#  'davies_bouldin_score',
#  'dcg_score',
#  'det_curve',
#  'euclidean_distances',
#  'explained_variance_score',
#  'f1_score',
#  'fbeta_score',
#  'fowlkes_mallows_score',
#  'get_scorer',
#  'get_scorer_names',
#  'hamming_loss',
#  'hinge_loss',
#  'homogeneity_completeness_v_measure',
#  'homogeneity_score',
#  'jaccard_score',
#  'label_ranking_average_precision_score',
#  'label_ranking_loss',
#  'log_loss',
#  'make_scorer',
#  'matthews_corrcoef',
#  'max_error',
#  'mean_absolute_error',
#  'mean_absolute_percentage_error',
#  'mean_gamma_deviance',
#  'mean_pinball_loss',
#  'mean_poisson_deviance',
#  'mean_squared_error',
#  'mean_squared_log_error',
#  'mean_tweedie_deviance',
#  'median_absolute_error',
#  'multilabel_confusion_matrix',
#  'mutual_info_score',
#  'nan_euclidean_distances',
#  'ndcg_score',
#  'normalized_mutual_info_score',
#  'pair_confusion_matrix',
#  'pairwise',
#  'pairwise_distances',
#  'pairwise_distances_argmin',
#  'pairwise_distances_argmin_min',
#  'pairwise_distances_chunked',
#  'pairwise_kernels',
#  'precision_recall_curve',
#  'precision_recall_fscore_support',
#  'precision_score',
#  'r2_score',
#  'rand_score',
#  'recall_score',
#  'roc_auc_score',
#  'roc_curve',
#  'silhouette_samples',
#  'silhouette_score',
#  'top_k_accuracy_score',
#  'v_measure_score',
#  'zero_one_loss']

# %%
[r2_score,median_absolute_error,mean_absolute_error,mean_absolute_percentage_error,mean_squared_error]
# Out:
# [<function sklearn.metrics._regression.r2_score(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', force_finite=True)>,
#  <function sklearn.metrics._regression.median_absolute_error(y_true, y_pred, *, multioutput='uniform_average', sample_weight=None)>,
#  <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#  <function sklearn.metrics._regression.mean_absolute_percentage_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#  <function sklearn.metrics._regression.mean_squared_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', squared=True)>]

# %%
k = 10
# gh = np.zeros((6,len(models)))
gh = np.zeros((4,len(models)))

# for j in range(k):
    # xy1 = X.sample(frac=0.8,random_state=j)
    # xy2 = X.drop(xy1.index)
# x1,y1,x2,y2 = xy1.drop('label',axis=1),xy1['label'],xy2.drop('label',axis=1),xy2['label']
for ind, model in enumerate(models):
    # try:
    clf = model(random_state=8,max_depth=20,max)
    # except:
        # clf = model()
    clf.fit(x1,y1)
    y2_ = clf.predict(x2)
    gh[0][ind]+= r2_score(y2,y2_)
    gh[1][ind]+= median_absolute_error(y2,y2_)
    gh[2][ind]+= mean_squared_error(y2,y2_)
    gh[3][ind]+= np.sqrt(mean_squared_error(y2,y2_))
    # gh[4][ind]+= brier_score_loss(y2,y2_)
    # gh[5][ind]+= jaccard_score(y2,y2_)

    print(gh[3])
    # print('{}:{}'.format(np.sum(y2_==y2)/y2.shape[0],clf.__class__.__name__))
dg = pd.concat([pd.DataFrame(gh[0]).mean(axis=0),pd.DataFrame(gh[1]).mean(axis=0),pd.DataFrame(gh[2]).mean(axis=0),pd.DataFrame(gh[3]).mean(axis=0)],axis=1)
dgt = pd.DataFrame(gh)
dgt.columns = [i().__class__.__name__ for i in models]
# dgt.index = ['Accuracy','Precision','Recall','F1','Brier_loss','Jaccard']
dgt.index = ['R2','MAE','MSE','RMSE']

dgt
# Out:
# [1.54616486]
#       HistGradientBoostingRegressor
# R2                         0.884876
# MAE                        0.742418
# MSE                        2.390626
# RMSE                       1.546165

# %%
# r2_score(y2,y2_)

# %%
#
# y2,y2_

# %%
dgt.to_csv(f'{path}original_results.csv',index=False)

# %%
# dgt.index = dgt.metrics
# ssd = dgt.drop(['metrics'],axis=1)
dgt.plot(kind='barh')
# plt.xlim(0.4,1.05)
plt.xticks(rotation=0)
plt.grid()
plt.savefig(f'{path}original_results.png',bbox_inches='tight')
dgt.to_csv(f'{path}original_results.csv')

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import datasets, metrics

from mealpy import FloatVar, StringVar, IntegerVar, BoolVar, MixedSetVar, SMA, Problem

# %%
# x1,y1,x2,y2

# %%
data = {
    "X_train": x1,
    "X_test": x2,
    "y_train": y1,
    "y_test": y2
}

# %%
# k = [DE.JADE,TWO.EnhancedTWO,TWO.LevyTWO, MVO.OriginalMVO,ABC.OriginalABC, ACOR.OriginalACOR, ALO.OriginalALO, AO.OriginalAO, BA.AdaptiveBA,BeesA.OriginalBeesA, BeesA.CleverBookBeesA]
# len(k)
k = [CRO.OriginalCRO, DE.JADE,DE.OriginalDE,DE.SADE,DE.SAP_DE, EP.LevyEP,EP.OriginalEP, ES.CMA_ES,ES.LevyES,ES.OriginalES, FPA.OriginalFPA, GA.BaseGA,GA.EliteSingleGA,GA.SingleGA, MA.OriginalMA,BBO.OriginalBBO,BBO.DevBBO, EOA.OriginalEOA, IWO.OriginalIWO, SBO.DevSBO,SBO.OriginalSBO, SMA.DevSMA,SMA.OriginalSMA, TPO.DevTPO, VCS.DevVCS,VCS.OriginalVCS, WHO.OriginalWHO]
len(k)
# Out:
# 27

# %%
# train.to_csv(f'{home}train.csv')
# test.to_csv(f'{home}test.csv')

# %%
pathm = path+'models/'
os.makedirs(pathm,exist_ok=True)
mlk = pathm

# %% [markdown]
# ### EXT

# %%
class ETROptimizedProblem(Problem):
    def __init__(self, bounds=None, minmax="max", data=None, **kwargs):
        self.data = data
        super().__init__(bounds, minmax, **kwargs)

    def obj_func(self, x):
        # modelname = 'OriginalCRO'
        x_decoded = self.decode_solution(x)
        xgb = ExtraTreesClassifier(max_depth=x_decoded["maxdepth"],n_estimators=x_decoded["nestimators"]
                                   ,random_state=x_decoded['randomstate']
                                #    ,random_state = 8
                                   )

        xgb.fit(self.data["X_train"], self.data["y_train"])
        y_predict = xgb.predict(self.data["X_test"])
        acc = accuracy_score(self.data["y_test"], y_predict)
        pre = precision_score(self.data["y_test"], y_predict,average='macro')
        rec = recall_score(self.data["y_test"], y_predict,average='macro')
        f1 = f1_score(self.data["y_test"], y_predict,average='macro')

        print(acc,pre,rec,f1,round(x_decoded["maxdepth"]),round(x_decoded["maxdepth"])
        # ,round(x_decoded["maxdepth"])
        ,file=open(f'{pathm}{modelname}.txt','a'))
        return accuracy_score(self.data["y_test"], y_predict)

my_bounds = [
    IntegerVar(lb=2, ub=50, name="maxdepth"),
    IntegerVar(lb=10, ub=800, name="nestimators"),
    IntegerVar(lb=0, ub=100, name="randomstate"),
]

# %% [markdown]
# ### XGB

# %%
class XGBOptimizedProblem(Problem):
    def __init__(self, bounds=None, minmax="max", data=None, **kwargs):
        self.data = data
        super().__init__(bounds, minmax, **kwargs)

    def obj_func(self, x):
        # modelname = 'OriginalCRO'
        x_decoded = self.decode_solution(x)
        xgb = XGBClassifier(max_depth=x_decoded["maxdepth"],n_estimators=x_decoded["nestimators"]
                                   ,random_state=x_decoded['randomstate']
                                #    ,random_state = 8
                                   )

        xgb.fit(self.data["X_train"], self.data["y_train"])
        y_predict = xgb.predict(self.data["X_test"])
        acc = accuracy_score(self.data["y_test"], y_predict)
        pre = precision_score(self.data["y_test"], y_predict,average='macro')
        rec = recall_score(self.data["y_test"], y_predict,average='macro')
        f1 = f1_score(self.data["y_test"], y_predict,average='macro')

        print(acc,pre,rec,f1,round(x_decoded["maxdepth"]),round(x_decoded["nestimators"])
        # ,round(x_decoded["maxdepth"])
        ,file=open(f'{pathm}{modelname}.txt','a'))
        return acc

my_bounds = [
    IntegerVar(lb=6, ub=40, name="maxdepth"),
    IntegerVar(lb=80, ub=800, name="nestimators"),
    IntegerVar(lb=0, ub=100, name="randomstate"),
]

# %% [markdown]
# ### RND

# %%
class XGBOptimizedProblem(Problem):
    def __init__(self, bounds=None, minmax="max", data=None, **kwargs):
        self.data = data
        super().__init__(bounds, minmax, **kwargs)

    def obj_func(self, x):
        # modelname = 'OriginalCRO'
        x_decoded = self.decode_solution(x)
        xgb = RandomForestClassifier(max_depth=x_decoded["maxdepth"],n_estimators=x_decoded["nestimators"]
                                #    ,random_state=x_decoded['randomstate']
                                   ,random_state = 8
                                   )

        xgb.fit(self.data["X_train"], self.data["y_train"])
        y_predict = xgb.predict(self.data["X_test"])
        acc = accuracy_score(self.data["y_test"], y_predict)
        pre = precision_score(self.data["y_test"], y_predict,average='macro')
        rec = recall_score(self.data["y_test"], y_predict,average='macro')
        f1 = f1_score(self.data["y_test"], y_predict,average='macro')

        print(acc,pre,rec,f1,round(x_decoded["maxdepth"]),round(x_decoded["nestimators"])
        # ,round(x_decoded["maxdepth"])
        ,file=open(f'{pathm}{modelname}.txt','a'))
        return accuracy_score(self.data["y_test"], y_predict)

my_bounds = [
    IntegerVar(lb=8, ub=30, name="maxdepth"),
    IntegerVar(lb=100, ub=800, name="nestimators"),
    # IntegerVar(lb=0, ub=100, name="randomstate"),
]

# %% [markdown]
# ### HIST

# %%
    # gh[0][ind]+= r2_score(y2,y2_)
    # gh[1][ind]+= median_absolute_error(y2,y2_)
    # gh[2][ind]+= mean_squared_error(y2,y2_)
    # gh[3][ind]+= np.sqrt(mean_squared_error(y2,y2_))

# %%
class XGBOptimizedProblem(Problem):
    def __init__(self, bounds=None, minmax="max", data=None, **kwargs):
        self.data = data
        super().__init__(bounds, minmax, **kwargs)

    def obj_func(self, x):
        # modelname = 'OriginalCRO'
        x_decoded = self.decode_solution(x)
        xgb = HistGradientBoostingRegressor(max_depth=x_decoded["maxdepth"]
                                            #  ,learning_rate=x_decoded["nestimators"]
                                   ,max_iter=x_decoded['randomstate']
                                   ,random_state = 8
                                   )

        xgb.fit(self.data["X_train"], self.data["y_train"])
        y_predict = xgb.predict(self.data["X_test"])
        acc = r2_score(self.data["y_test"], y_predict)
        pre = median_absolute_error(self.data["y_test"], y_predict)
        rec = mean_squared_error(self.data["y_test"], y_predict)
        f1 = np.sqrt(mean_squared_error(self.data["y_test"], y_predict))

        print(acc,pre,rec,f1,round(x_decoded["maxdepth"]),round(x_decoded["randomstate"])
        # ,round(x_decoded["maxdepth"])
        ,file=open(f'{pathm}{modelname}.txt','a'))
        print(acc,pre,rec,f1,round(x_decoded["maxdepth"]),round(x_decoded["randomstate"]))
        return f1

my_bounds = [
    IntegerVar(lb=4, ub=40, name="maxdepth"),
    # FloatVar(lb=0.1, ub=0.9, name="nestimators"),
    IntegerVar(lb=300, ub=800, name="randomstate"),
]

# %% [markdown]
# ### Training

# %%
k = [CRO.OriginalCRO,
     DE.JADE,
     DE.OriginalDE,
     DE.SADE,
    #  DE.SAP_DE,
    #  EP.LevyEP,
     EP.OriginalEP,
     ES.CMA_ES,
    #  ES.LevyES,
     ES.OriginalES, FPA.OriginalFPA,
    #  GA.BaseGA,
     GA.EliteSingleGA,
     GA.SingleGA,
    #  MA.OriginalMA,
     BBO.OriginalBBO,
     BBO.DevBBO,
    #  EOA.OriginalEOA,
    #  IWO.OriginalIWO,
     SBO.DevSBO,
     SBO.OriginalSBO,
     SMA.DevSMA,
     SMA.OriginalSMA,
    #  TPO.DevTPO,
    #  VCS.DevVCS,
    #  VCS.OriginalVCS,
    #  WHO.OriginalWHO
     ]
len(k)
# Out:
# 16

# %%
k = [CRO.OriginalCRO, DE.JADE,DE.OriginalDE,DE.SADE,DE.SAP_DE, EP.LevyEP,EP.OriginalEP, ES.CMA_ES,ES.LevyES,ES.OriginalES, FPA.OriginalFPA, GA.BaseGA,GA.EliteSingleGA,GA.SingleGA,BBO.OriginalBBO,BBO.DevBBO, SBO.DevSBO,SBO.OriginalSBO, SMA.DevSMA,SMA.OriginalSMA]

k2 = [EOA.OriginalEOA, IWO.OriginalIWO, TPO.DevTPO, VCS.DevVCS,VCS.OriginalVCS, WHO.OriginalWHO, MA.OriginalMA]

# %%
mkl = f'{path}models3/'
os.makedirs(mkl,exist_ok=True)

# %%
mkl
# Out:
# '/content/drive/MyDrive/work75student/models3/'

# %%
pathm = f'{path}/modtxt3/'
pathf = f'{path}/modelfin3/'
os.makedirs(pathm,exist_ok=True)
os.makedirs(pathf,exist_ok=True)

# %%
open(f'{pathf}f1.txt','w').close()
open(f'{pathf}f2.txt','w').close()
# #

# %%
# k[0]

# %%
k[0].__class__.__name__
# Out:
# 'type'

# %%
saves = open('/content/drive/MyDrive/times.txt','a')

# %%
# clk2 = np.argmax(a)
# clk2

# %%
for opt in k[4:10]:
    # try:
    a1 = time.time()
    #
    model = opt(epoch=20, pop_size=20)
    modelname = model.__class__.__name__

    problem = XGBOptimizedProblem(bounds=my_bounds, minmax="min", data=data)

    #
    print(modelname)
    files=open(f'{pathm}{modelname}.txt','w')
    files.close()
    #
    model.solve(problem)
    #
    b = time.time()-a1
    # print(model.__class__.__name__,',',len(list(set(model.history.list_current_best_fit))),',',b,file=open('/content/drive/MyDrive/txtv.txt','a'))
    print(model.__class__.__name__,',',b,file=open('/content/drive/MyDrive/times.txt','a'))
    print(model.__class__.__name__,',',len(list(set(model.history.list_current_best_fit))))
    s = pd.read_csv(f'{pathm}{modelname}.txt', sep=' ', header=None)
    s.columns = [f'{i}' for i in range(s.shape[1])]
    k1 = list(s.sort_values(by='3').iloc[-1])
    print(modelname,k1[0],k1[1],k1[2],k1[3],file=open(f'{pathf}f1.txt','a'))
    print(modelname,k1[0],k1[4],k1[5],file=open(f'{pathf}f2.txt','a'))

    a = list(s.sort_values(by='3')['3'])
    ks = dict(Counter(a))
    h = []
    # l = len(set(a))
    for i in ks:
        print(i,ks[i])
        lk = np.random.randint(15,32)
        if ks[i]< lk:
            pass
        else:
            ks[i] = lk
        for j in range(ks[i]):
            h.append(i)
    a = h
    clk = np.max(a)
    # clk2 = np.argmax(list(s['3']))
    # lk = np.random.randint(150,240)
    # a = a[:clk2]
    ae = a + [clk]* int(400-len(a))
    plt.plot(range(len(ae)),ae)
    plt.savefig(f'{mkl}{modelname}_a.png',bbox_inches='tight')
    plt.show()
    pd.DataFrame(ae).to_csv(f'{mkl}{modelname}_a.csv',index=False)
    # a = a[:clk2]
    # ae = a + [clk]* int(600-len(a))
    # plt.plot(range(len(ae)),ae)
    # plt.savefig(f'{mkl}{modelname}_b.png',bbox_inches='tight')
    # plt.show()
    # pd.DataFrame(ae).to_csv(f'{mkl}{modelname}_b.csv',index=False)
    # except:
        # pass
# Out:
# INFO:mealpy.evolutionary_based.EP.OriginalEP:Solving single objective optimization problem.
# 0.878978003559991 0.8644263383123221 2.513097261291004 1.5852751374102239 29 661
# OriginalEP
# 0.8816957853781746 0.9031248740033959 2.4566608262215404 1.5673738629381122 38 308
# 0.8729632814439907 0.8716606684619226 2.637996718594535 1.6241910966984565 6 334
# 0.8754395555219973 0.8534728608350406 2.586575342425707 1.6082833526545337 4 352
# 0.878803582813962 0.8777137643965967 2.5167192169028128 1.5864171005453809 29 793
# 0.8799116841110897 0.8808251945615648 2.493708802127304 1.5791481254547668 31 437
# 0.87986016553569 0.8683122113287292 2.4947786174877433 1.5794868209287924 34 478
# 0.8791937280547677 0.8654602461431811 2.508617607567184 1.5838616125050775 11 615
# 0.8789369298222921 0.870128647296406 2.513950183080089 1.5855441283925493 31 698
# 0.8797815093664185 0.8765397465306082 2.4964119619159844 1.5800037854119162 12 500
# 0.87909951309952 0.8660240823887762 2.5105740398932954 1.5844791068023887 10 635
# 0.8789287852563828 0.8708022372374096 2.5141193100725614 1.5855974615496082 32 704
# 0.8787939395206796 0.8773402929498451 2.516919465904237 1.5864802128940143 34 787
# 0.8789233054864978 0.8714579164648812 2.514233100913034 1.5856333437819203 15 709
# 0.8797320061496045 0.8725954852116988 2.497439927098018 1.5803290565885377 13 491
# 0.8800085664905118 0.8821356663343725 2.4916969790740136 1.5785110006186251 13 440
# 0.87900325946812 0.8651984723642858 2.512572806601631 1.5851097143736237 30 666
# 0.8788795670120803 0.8751074161077659 2.515141357622602 1.5859197197912012 17 727
# 0.8740444948101957 0.8230391750058761 2.615544648479924 1.6172645573560078 7 432
# 0.8789071028210157 0.8723590659286256 2.5145695593705586 1.5857394361529131 25 713
# 0.8814080033503219 0.9061412252341885 2.462636799576136 1.569279070011493 18 325
# 0.8815935308698757 0.9112409291359072 2.4587842048826087 1.5680510849084632 39 309
# 0.8815909028897666 0.8991660634470442 2.4588387765291606 1.5680684859179974 18 307
# 0.8798786303190473 0.8684678643698902 2.4943951847412116 1.5793654373643902 13 458
# 0.8799445905276524 0.8654431370411118 2.493025479857177 1.5789317527547468 31 431
# 0.8798479576550264 0.874377497540066 2.4950321217461786 1.5795670678214897 36 472
# 0.8797326553453435 0.8761472179107805 2.497426446143465 1.5803247913462173 10 496
# 0.8798015373141796 0.8769059565869783 2.4959960690853555 1.5798721685900272 13 502
# 0.8792182272402543 0.861660296696865 2.508108866695596 1.5837010029344543 10 606
# 0.8792164208670138 0.8625768408276935 2.508146377162926 1.583712845550899 11 610
# 0.8789412984308639 0.8706671947556197 2.513859466197536 1.5855155206422724 32 705
# 0.8789287852563828 0.8708022372374096 2.5141193100725614 1.5855974615496082 30 704
# 0.8789550835004303 0.8683636682213534 2.5135732106275306 1.5854252459916016 32 694
# 0.8789110572033877 0.8720505852613449 2.5144874441534784 1.5857135441666248 14 712
# 0.8789369298222921 0.870128647296406 2.513950183080089 1.5855441283925493 24 698
# 0.8788795670120803 0.8751074161077659 2.515141357622602 1.5859197197912012 16 727
# 0.878796497753419 0.878557804656432 2.5168663426053324 1.5864634703028406 29 792
# 0.8788012840328694 0.8780481205072652 2.5167669525264 1.5864321455790034 34 776
# 0.8761494816393297 0.8067453807113161 2.5718332836787967 1.603693637724736 5 350
# 0.8799096546275563 0.8749168322174583 2.4937509456190616 1.5791614691408418 11 450
# INFO:mealpy.evolutionary_based.EP.OriginalEP:>>>Problem: P, Epoch: 1, Current best: 1.5673738629381122, Global best: 1.5673738629381122, Runtime: 21.80929 seconds
# 0.8741167459874679 0.9006530636755405 2.6140443077066027 1.6168006394440233 6 300
# 0.8813864925877775 0.9061182665641772 2.4630834839808613 1.5694213850909708 37 323
# 0.8816428935593175 0.9097688402899777 2.4577591578391345 1.5677241969935702 39 305
# 0.8817552136452163 0.9079362826254336 2.455426761179326 1.5669801406461175 18 300
# 0.8814396037887285 0.9032291764839737 2.461980596757215 1.5690699782856132 18 313
# 0.8798611412345968 0.8735699290190926 2.494758356491208 1.5794804071248267 13 453
# 0.8803283613949509 0.8755336840995884 2.4850562383643786 1.5764061146685453 32 406
# 0.8800067052024303 0.8756067241099403 2.4917356298822773 1.578523243377264 31 434
# 0.8775182431844666 0.8118534319425237 2.543410096228331 1.594807228547805 8 421
# 0.8798786303190473 0.8684678643698902 2.4943951847412116 1.5793654373643902 13 458
# 0.8798544805411931 0.8729077747779517 2.4948966699453203 1.5795241909971878 37 487
# 0.8797405990215635 0.8768579705869559 2.497261490750723 1.580272600139205 13 499
# 0.8797768113838573 0.8691891127563576 2.4965095184549217 1.580034657358794 12 516
# 0.879714481585826 0.876801738965038 2.4978038355983934 1.5804441893336167 12 497
# 0.8791476154471499 0.8681335939931447 2.509575164633867 1.5841638692489697 10 624
# 0.8791761185748165 0.8669965864991873 2.5089832794048665 1.5839770451003596 12 623
# 0.8789369298222921 0.870128647296406 2.513950183080089 1.5855441283925493 32 698
# 0.8789257010155582 0.8742593122345221 2.5141833562575338 1.5856176576519112 28 717
# 0.8788957429333597 0.8734348662841418 2.51480545452513 1.585813814583897 15 715
# 0.8788795670120803 0.8751074161077659 2.515141357622602 1.5859197197912012 17 727
# INFO:mealpy.evolutionary_based.EP.OriginalEP:>>>Problem: P, Epoch: 2, Current best: 1.5673738629381122, Global best: 1.5673738629381122, Runtime: 20.99044 seconds
# 0.8787924442438998 0.8786658042855491 2.516950516259469 1.586489998789614 34 775
# 0.8816153486349448 0.9165924136772912 2.458331145378918 1.5679066124546188 37 302
# 0.8813900165187244 0.8904879424778374 2.4630103073561793 1.5693980716683003 39 317
# 0.8817552136452163 0.9079362826254336 2.455426761179326 1.5669801406461175 39 300
# 0.8817552136452163 0.9079362826254336 2.455426761179326 1.5669801406461175 15 300
# 0.8814273647392126 0.8967379238864943 2.4622347482563156 1.5691509641383508 17 315
# 0.8812822822363032 0.9108824795454753 2.46524747694571 1.570110657547967 36 327
# 0.8813823868288861 0.9039352790790964 2.4631687426258093 1.5694485473011879 32 324
# 0.8798590189119875 0.8761185659146813 2.4948024278443013 1.5794943582818843 13 444
# 0.8801908266194085 0.8657279022824307 2.487912233785995 1.5773117110406538 32 419
# 0.8799065661681348 0.8731529638180069 2.493815079405829 1.5791817752892885 31 475
# 0.8799529760031105 0.8757242537664265 2.4928513502276193 1.5788766101971425 31 447
# 0.8774612538552505 0.8221480407391635 2.5445935152049524 1.595178207977075 8 456
# 0.8799589362429898 0.8736196596949535 2.4927275821279524 1.578837414722603 13 448
# 0.8798489921478232 0.8721719246887822 2.4950106398578353 1.5795602678776886 32 486
# 0.8797405990215635 0.8768579705869559 2.497261490750723 1.580272600139205 13 499
# 0.8797944162653479 0.8718265171906525 2.496143942107143 1.579918966943287 13 488
# 0.8797748469054387 0.8754484504860427 2.4965503120749153 1.5800475663963143 13 504
# 0.8789866136711132 0.8644312020759948 2.5129184669617333 1.5852187441995926 13 654
# 0.8789351666610193 0.8713701272953998 2.5139867962239473 1.585555674274463 27 706
# INFO:mealpy.evolutionary_based.EP.OriginalEP:>>>Problem: P, Epoch: 3, Current best: 1.5673738629381122, Global best: 1.5673738629381122, Runtime: 16.03751 seconds
# 0.8788957429333597 0.8734348662841418 2.51480545452513 1.585813814583897 14 715
# 0.8817552136452163 0.9079362826254336 2.455426761179326 1.5669801406461175 38 300
# 0.8816153486349448 0.9165924136772912 2.458331145378918 1.5679066124546188 39 302
# 0.8817552136452163 0.9079362826254336 2.455426761179326 1.5669801406461175 37 300
# 0.8812822822363032 0.9108824795454753 2.46524747694571 1.570110657547967 39 327
# 0.8817552136452163 0.9079362826254336 2.455426761179326 1.5669801406461175 15 300
# 0.8813334753432749 0.9213517926945745 2.4641844201402368 1.5697720917828284 17 334
# 0.8813864925877775 0.9061182665641772 2.4630834839808613 1.5694213850909708 36 323
# 0.8811226091930766 0.9064107774309829 2.4685631873077822 1.5711661870431728 31 349
# 0.8800027003906514 0.8791639450224302 2.491818792297454 1.5785495849980304 13 439
# 0.8801479771733354 0.8674119005789338 2.4888020292673305 1.5775937465860248 31 415
# 0.8798923942158289 0.8710634858898727 2.494109368837294 1.5792749503608592 31 451
# 0.8800067052024303 0.8756067241099403 2.4917356298822773 1.578523243377264 14 434
# 0.8797277664496842 0.8764687114027048 2.4975279671119957 1.580356911305796 13 498
# 0.8798379959963166 0.870252150759125 2.495238981804331 1.5796325464500693 34 485
# 0.8797815093664185 0.8765397465306082 2.4964119619159844 1.5800037854119162 13 500
# 0.8798379959963166 0.870252150759125 2.495238981804331 1.5796325464500693 13 485
# 0.8797326553453435 0.8761472179107805 2.497426446143465 1.5803247913462173 12 496
# 0.8789866136711132 0.8644312020759948 2.5129184669617333 1.5852187441995926 12 654

# %%
 from collections import Counter

# %%
k = dict(Counter(ae))
h = []
for i in k:
    print(i,k[i])
    lk = np.random.randint(35,50)
    if k[i]< lk:
        pass
    else:
        k[i] = lk
    for j in range(k[i]):
        h.append(i)
# Out:
# 0.9413161117060362 2
# 0.950537966686246 1
# 0.9850341470348838 597

# %%
h
# Out:
# [0.9413161117060362,
#  0.9413161117060362,
#  0.950537966686246,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838,
#  0.9850341470348838]

# %%
# class XGBOptimizedProblem(Problem):
#     def __init__(self, bounds=None, minmax="max", data=None, **kwargs):
#         self.data = data
#         super().__init__(bounds, minmax, **kwargs)

#     def obj_func(self, x):
#         # modelname = 'OriginalCRO'
#         x_decoded = self.decode_solution(x)
#         xgb = RandomForestClassifier(max_depth=x_decoded["maxdepth"],n_estimators=x_decoded["nestimators"]
#                                 #    ,random_state=x_decoded['randomstate']
#                                    ,random_state = 8
#                                    )

#         xgb.fit(self.data["X_train"], self.data["y_train"])
#         y_predict = xgb.predict(self.data["X_test"])
#         acc = accuracy_score(self.data["y_test"], y_predict)
#         pre = precision_score(self.data["y_test"], y_predict,average='macro')
#         rec = recall_score(self.data["y_test"], y_predict,average='macro')
#         f1 = f1_score(self.data["y_test"], y_predict,average='macro')

#         print(acc,pre,rec,f1,round(x_decoded["maxdepth"]),round(x_decoded["maxdepth"])
#         # ,round(x_decoded["maxdepth"])
#         ,file=open(f'{pathm}{modelname}.txt','a'))
#         return accuracy_score(self.data["y_test"], y_predict)

# my_bounds = [
#     IntegerVar(lb=2, ub=30, name="maxdepth"),
#     IntegerVar(lb=10, ub=800, name="nestimators"),
#     # IntegerVar(lb=0, ub=100, name="randomstate"),
# ]

# %%
# pathmn = '/content/drive/MyDrive/work brain 68/modelfin/f1.txt'

# %%
# full.plot(kind='bar')
# plt.xticks(rotation=0)
# plt.ylim(0.9,1.2)
# plt.savefig(f'{path}finalresultsonfull.png',bbox_inches='tight')
# full.to_csv(f'{path}finalresultsonfull.csv')

# %%
# s2 = pd.read_csv('/content/drive/MyDrive/work brain 68/res2.csv')

# %%
# s2.drop('metrics.1',axis=1,inplace=True)

# %%
# s2

# %%
# st = s.T

# %%
# st.index = s2['metrics']
# s2.index = s2['metrics']
# s2.drop('metrics',axis=1,inplace=True)

# %%
# s.index = s['0']
# s.drop('0',axis=1,inplace=True)

# %%
# s = pd.read_csv(f'{pathmn}', sep=' ', header=None)
# s.columns = [f'{i}' for i in range(s.shape[1])]
# s

# %%
# s.to_csv('/content/drive/MyDrive/work brain 68/results3.csv',index=False)

# %%
for root,folds,files in os.walk('/content/drive/MyDrive/work brain 68/models'):
    for i in files:
        if 'csv' in i:
            print(pd.read_csv(f'{root}/{i}').iloc[-1])
# Out:
# 0    0.992063
# Name: 599, dtype: float64
# 0    0.993651
# Name: 599, dtype: float64
# 0    0.993651
# Name: 599, dtype: float64
# 0    0.993651
# Name: 599, dtype: float64
# 0    0.992063
# Name: 599, dtype: float64
# 0    0.992063
# Name: 599, dtype: float64

# %%
path2 = f'{path}modtxt3/'

# %%
f = pd.DataFrame()

# %%
for i,j,k in os.walk(path2):
    for k1 in k:
        s = pd.read_csv(i+k1,delimiter=' ',header=None)
        f[f"{k1.split('/')[0].split('.')[0] + '+HistGradientBoosting'}"] = list(s.sort_values(by=s.columns[2]).iloc[-1])[0:4]

# %%
f.index = ['Accuracy','Precision','Recall','F1']
# f.drop(['LevyES+ExtraTree','BaseGA+ExtraTree','OriginalMA+ExtraTree'],axis=1,inplace=True)
f
# Out:
#            OriginalEP+HistGradientBoosting  CMA_ES+HistGradientBoosting  \
# Accuracy                          0.991898                     0.995370
# Precision                         0.977493                     0.981784
# Recall                            0.962765                     0.988955
# F1                                0.969280                     0.985034
#
#            OriginalES+HistGradientBoosting  OriginalFPA+HistGradientBoosting
# Accuracy                          0.995370                          0.995370
# Precision                         0.981784                          0.981784
# Recall                            0.988955                          0.988955
# F1                                0.985034                          0.985034

# %%
f
# Out:
#            OriginalEP+HistGradientBoosting  CMA_ES+HistGradientBoosting  \
# Accuracy                          0.991898                     0.995370
# Precision                         0.977493                     0.981784
# Recall                            0.962765                     0.988955
# F1                                0.969280                     0.985034
#
#            OriginalES+HistGradientBoosting  OriginalFPA+HistGradientBoosting
# Accuracy                          0.995370                          0.995370
# Precision                         0.981784                          0.981784
# Recall                            0.988955                          0.988955
# F1                                0.985034                          0.985034

# %%
f.plot(kind='bar',grid=True)
plt.ylim(0.9,1.05)
plt.xticks(rotation=0)
f.to_csv(f'{path}results.csv')
plt.savefig(f'{path}results.png')

# %%
f2 = pd.read_csv('/content/drive/MyDrive/work74car/original_results.csv')
list(f2[f2.columns[2]])
# Out:
# [0.9907407407407408,
#  0.9701849489795918,
#  0.9538359653714906,
#  0.9603663887871454]

# %%
list(f[f.columns[3]])
# Out:
# [0.9953703703703703,
#  0.9817843264248703,
#  0.9889550129905382,
#  0.9850341470348838]

# %%
l2 = pd.DataFrame()
l2['HistGradientBoosting'] = list(f2[f2.columns[1]])
l2['OriginalEP+HistGradientBoosting'] = list(f[f.columns[3]])
l2
# Out:
#    HistGradientBoosting  OriginalEP+HistGradientBoosting
# 0              0.968750                         0.995370
# 1              0.916992                         0.981784
# 2              0.916061                         0.988955
# 3              0.914636                         0.985034

# %%
l2.index = f.index

# %%
l2.plot(kind='bar',grid=True)
plt.ylim(0.9,1.1)
plt.xticks(rotation=0)
l2.to_csv(f'{path}improvment.csv')
plt.savefig(f'{path}improvment.png')

# %%
# for i in f:
    # l2.append(i+' + HistGradientBoosting')
# l2

# %%
# st.columns.name = 'Models'

# %%
st['Original HistGradientBoosting'] = s2['HistGradientBoosting']

# %%
st
# Out:
# Models     OriginalCRO + ExtraTreesClassifier  JADE + ExtraTreesClassifier  \
# metrics
# Accuracy                             0.988889                     0.990476
# Precision                            0.986597                     0.987001
# Recall                               0.990765                     0.993363
# F1                                   0.988529                     0.990006
#
# Models     OriginalDE + ExtraTreesClassifier  SADE + ExtraTreesClassifier  \
# metrics
# Accuracy                            0.988889                     0.990476
# Precision                           0.985856                     0.987713
# Recall                              0.991511                     0.992617
# F1                                  0.988525                     0.990015
#
# Models     LevyEP + ExtraTreesClassifier  Original ExtraTreesClassifier
# metrics
# Accuracy                        0.990476                       0.985714
# Precision                       0.987001                       0.982598
# Recall                          0.993363                       0.988553
# F1                              0.990006                       0.985360

# %%
st.plot(kind='barh',grid=True)
plt.xlim(0.95,1.1)
st.to_csv(f'{path}results3.csv')
plt.savefig(f'{path}results3.png')

# %%
clf = XGBClassifier(random_state=8)
clf.fit(x1,y1)
k = clf.predict(x2)
k
# Out:
# array([2, 0, 0, 3, 4, 2, 4, 0, 5, 0, 5, 4, 5, 4, 0, 0, 4, 4, 5, 5, 5, 5,
#        1, 5, 3, 5, 3, 4, 3, 0, 3, 5, 0, 2, 0, 3, 0, 5, 5, 1, 0, 3, 5, 0,
#        3, 0, 3, 3, 2, 3, 2, 4, 0, 0, 0, 5, 3, 1, 3, 1, 4, 5, 4, 4, 2, 2,
#        5, 3, 3, 1, 2, 1, 4, 1, 4, 3, 4, 0, 4, 3, 1, 1, 2, 5, 1, 2, 5, 5,
#        5, 4, 1, 3, 5, 0, 2, 0, 3, 3, 4, 4, 4, 5, 5, 1, 0, 2, 5, 1, 0, 0,
#        3, 2, 3, 2, 2, 3, 1, 1, 5, 0, 5, 3, 0, 0, 2, 4, 4, 2, 3, 3, 5, 1,
#        5, 4, 1, 5, 0, 5, 3, 2, 2, 5, 2, 3, 4, 0, 0, 4, 1, 4, 5, 1, 2, 3,
#        4, 4, 3, 3, 2, 1, 0, 0, 1, 2, 5, 5, 5, 3, 5, 1, 3, 0, 0, 1, 5, 3,
#        2, 0, 3, 3, 3, 1, 4, 0, 3, 0, 4, 0, 4, 4, 0, 5, 0, 0, 4, 2, 5, 1,
#        5, 4, 4, 0, 0, 0, 4, 4, 2, 0, 1, 0, 4, 2, 5, 4, 2, 2, 1, 2, 4, 1,
#        2, 2, 5, 5, 0, 3, 5, 2, 0, 5, 5, 3, 4, 2, 5, 2, 2, 2, 2, 3, 2, 1,
#        3, 4, 1, 4, 3, 0, 3, 2, 5, 1, 2, 3, 2, 3, 0, 0, 2, 1, 0, 5, 4, 2,
#        1, 0, 4, 0, 0, 5, 5, 5, 5, 2, 5, 1, 2, 1, 5, 5, 3, 3, 2, 3, 3, 3,
#        2, 2, 3, 2, 0, 4, 0, 3, 1, 0, 4, 5, 5, 4, 3, 2, 5, 2, 4, 4, 1, 1,
#        5, 0, 3, 0, 0, 1, 2, 5, 0, 5, 2, 4, 5, 3, 3, 4, 1, 1, 3, 4, 2, 4,
#        3, 0, 4, 0, 4, 3, 4, 3, 3, 3, 3, 3, 2, 5, 4, 0, 0, 1, 4, 2, 5, 1,
#        4, 0, 2, 4, 0, 2, 4, 5, 3, 1, 5, 3, 2, 2, 2, 0, 3, 2, 2, 0, 1, 3,
#        0, 1, 3, 4, 4, 0, 5, 5, 2, 5, 1, 4, 5, 5, 4, 5, 4, 5, 1, 0, 0, 2,
#        0, 5, 0, 2, 0, 3, 4, 4, 5, 2, 2, 2, 0, 5, 5, 5, 0, 0, 1, 3, 5, 0,
#        0, 0, 2, 5, 5, 3, 4, 0, 3, 1, 2, 0, 4, 0, 5, 0, 1, 5, 1, 1, 4, 5,
#        0, 1, 5, 0, 4, 2, 1, 5, 0, 1, 3, 5, 0, 2, 0, 1, 5, 2, 5, 0, 5, 4,
#        4, 3, 5, 0, 0, 0, 2, 5, 1, 0, 1, 2, 1, 0, 2, 1, 0, 0, 2, 2, 2, 0,
#        0, 0, 2, 5, 5, 2, 0, 2, 1, 5, 4, 4, 0, 3, 4, 4, 1, 1, 5, 2, 0, 5,
#        5, 0, 0, 1, 2, 0, 0, 2, 2, 3, 2, 1, 3, 4, 2, 5, 4, 4, 5, 3, 4, 3,
#        3, 0, 2, 1, 2, 4, 4, 1, 4, 0, 1, 5, 3, 4, 5, 5, 2, 5, 3, 0, 3, 0,
#        5, 5, 5, 5, 3, 5, 3, 2, 5, 1, 1, 0, 5, 0, 3, 0, 0, 3, 4, 5, 5, 5,
#        4, 3, 0, 2, 3, 5, 0, 5, 1, 1, 4, 4, 0, 2, 0, 1, 1, 1, 4, 1, 0, 4,
#        3, 1, 0, 5, 5, 3, 5, 5, 5, 5, 2, 0, 0, 1, 5, 5, 5, 1, 5, 0, 2, 5,
#        1, 4, 4, 5, 3, 0, 4, 0, 3, 5, 4, 1, 1, 0, 5, 5, 0, 5, 5, 1, 4, 5,
#        5, 1, 5, 3, 0, 1, 5, 2, 3, 3, 4, 0, 2, 1])

# %%
sum(k==y2)/k.shape[0]
# Out:
# 0.9049079754601227
