# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
plt.style.use('classic')

# %%
x = np.linspace(0,3*np.pi,100)

# %%
# import matplotlib.pyplot as plt
# csfont = {'fontname':'Times New Roman'}
# // write your code related to basemap here
# plt.title('title',**csfont)
# plt.show()
plt.rcParams["font.family"] = "Times New Roman"

# %%
plt.plot(x,np.sin(x),'-b')
plt.plot(x,np.cos(x),'--r')
plt.title('Hello')
plt.savefig('./g.png')

# %%
from IPython.display import Image

# %%
p = Image('./g.png')

# %%
plt.figure()

plt.subplot(3,1,1)
plt.plot(x,np.sin(x))

plt.subplot(3,1,2)
plt.plot(x,np.sin(x))

plt.subplot(3,1,3)
plt.plot(x,np.cos(x))

# %%
fig, ax = plt.subplots(3,sharex=True)
ax[0].plot(x,np.sin(x),'g',label='sin')
# ax[0].legend()
ax[0].set(title="sin(x)")
ax[1].plot(x,np.cos(x),'y',label='cos')
# ax[1].legend()
ax[1].set(title="cos(x)")
ax[2].plot(x,np.tan(x),'r',label='tan')
# ax[2].legend()
ax[2].set(title="tan(x)")
# Out:
# [Text(0.5, 1.0, 'tan(x)')]

# %%
plt.style.use('seaborn-whitegrid')

# %%
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 30)
ax.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), 'or', label='cos(x)')
plt.axis('equal')
plt.legend();

# %%
rng = np.random.RandomState(0)
plt.figure(dpi=200)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
    label="'{0}'".format(marker))

plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
x,y = range(5), rng.randint(0,5,(5,1))

# %%
x = np.linspace(0,3*np.pi,30)

# %%
plt.plot(x, np.sin(x), '-p', color='grey',
markersize=15, linewidth=4,
markerfacecolor='white',
markeredgecolor='gray',
markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %%
rng = np.random.RandomState(1)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
cmap='viridis')
# plt.grid(False)
plt.colorbar(); # show color scale
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\254050118.py:9: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(); # show color scale

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.2,
s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);
# plt.colorbar()

# %%
x = np.linspace(0, 10, 30)
dy = 0.9
y = np.sin(x) + dy * np.random.randn(30)
plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
ecolor='lightgray', elinewidth=3, capsize=0);

# %%
# from sklearn.gaussian_process import

# %%
from sklearn.gaussian_process import GaussianProcessRegressor as GaussianProcess
# define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)
# Compute the Gaussian process fit
gp = GaussianProcess()
gp.fit(xdata[:, np.newaxis], ydata)
xfit = np.linspace(0, 10, 1000)
yfit= gp.predict(xfit[:, np.newaxis])
# dyfit = 2 * np.sqrt((yfit-model(xfit))) # 2*sigma ~ 95% confidence region

# %%
dyfit = np.random.rand(len(yfit))
plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')
plt.fill_between(xfit, yfit - dyfit, yfit + dyfit,
color='gray', alpha=0.15)
plt.xlim(0, 10);

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
Z.shape
# Out:
# (40, 50)

# %%
plt.contour(X, Y, Z,20 , colors='black');

# %%
contours = plt.contour(X, Y, Z, 4, cmap='RdGy');
plt.clabel(contours, inline=True, fontsize=8)
plt.colorbar();

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
cmap='RdGy', alpha=0.5)
plt.colorbar();
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\3955585291.py:5: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar();

# %%
data = np.random.randn(1000)
plt.hist(data);

# %%
plt.hist(data, bins=30, alpha=0.5,
histtype='stepfilled', color='steelblue',
edgecolor='none');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.3, bins=60)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %%
mean = [0, 0]
cov = [[0.2, 2],
       [2, 1]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\630358904.py:4: RuntimeWarning: covariance is not positive-semidefinite.
#   x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\3333391642.py:1: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.hist2d(x, y, bins=30, cmap='Blues')
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\3333391642.py:2: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = plt.colorbar()

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\1453572288.py:2: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = plt.colorbar(label='count in bin')

# %%
from scipy.stats import gaussian_kde
# fit an array of size [Ndim, Nsamples]
data = np.vstack([x, y])
kde = gaussian_kde(data)
# evaluate on a regular grid
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# %%
# Plot the result as an image
plt.imshow(Z.reshape(Xgrid.shape),
origin='lower', aspect='auto',
extent=[-3.5, 3.5, -6, 6],
cmap='Blues')
cb = plt.colorbar()
cb.set_label("density")
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\273480503.py:6: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = plt.colorbar()

# %%
Xgrid.ravel().shape
# Out:
# (1600,)

# %%
xgrid
# Out:
# array([-3.5       , -3.32051282, -3.14102564, -2.96153846, -2.78205128,
#        -2.6025641 , -2.42307692, -2.24358974, -2.06410256, -1.88461538,
#        -1.70512821, -1.52564103, -1.34615385, -1.16666667, -0.98717949,
#        -0.80769231, -0.62820513, -0.44871795, -0.26923077, -0.08974359,
#         0.08974359,  0.26923077,  0.44871795,  0.62820513,  0.80769231,
#         0.98717949,  1.16666667,  1.34615385,  1.52564103,  1.70512821,
#         1.88461538,  2.06410256,  2.24358974,  2.42307692,  2.6025641 ,
#         2.78205128,  2.96153846,  3.14102564,  3.32051282,  3.5       ])

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %%
ax.legend(loc='upper left', frameon=False)
fig

# %%
ax.legend(frameon=False, loc='lower center', ncol=2)
fig

# %%
# x = np.array([1,2,3,4]) + np.pi * np.arange(0, 2, 0.5)
np.sin(x[:,np.newaxis] + np.pi * np.arange(0, 2, 0.5))
# Out:
# array([[ 0.00000000e+00,  1.00000000e+00,  1.22464680e-16,
#         -1.00000000e+00],
#        [ 1.00098428e-02,  9.99949900e-01, -1.00098428e-02,
#         -9.99949900e-01],
#        [ 2.00186827e-02,  9.99799606e-01, -2.00186827e-02,
#         -9.99799606e-01],
#        ...,
#        [-5.27114986e-01, -8.49793970e-01,  5.27114986e-01,
#          8.49793970e-01],
#        [-5.35594881e-01, -8.44475058e-01,  5.35594881e-01,
#          8.44475058e-01],
#        [-5.44021111e-01, -8.39071529e-01,  5.44021111e-01,
#          8.39071529e-01]])

# %%
y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, 0.5))
lines = plt.plot(x, y)

plt.legend(lines[:2], ['first', 'second'])

# %%
n,m = np.array([1,2,3]),np.array([4,5,6])
n.shape,m.shape
# Out:
# ((3,), (3,))

# %%
n = n[np.newaxis,:]
n.shape,m.shape
# Out:
# ((1, 3), (3,))

# %%
n + m
# Out:
# array([[5, 7, 9]])

# %%
n = n[:,np.newaxis]
n.shape,m.shape
# Out:
# ((1, 1, 3), (3,))

# %%
n + m
# Out:
# array([[[5, 7, 9]]])

# %%
n
# Out:
# array([[[1, 2, 3]]])

# %%
m
# Out:
# array([4, 5, 6])

# %%
# LOOK HERE

# cities = pd.read_csv('data/california_cities.csv')
# # Extract the data we're interested in
# lat, lon = cities['latd'], cities['longd']
# population, area = cities['population_total'], cities['area_total_km2']
# # Scatter the points, using size and color but no label
# plt.scatter(lon, lat, label=None,
# c=np.log10(population), cmap='viridis',
# s=area, linewidth=0, alpha=0.5)
# plt.axis(aspect='equal')
# plt.xlabel('longitude')
# plt.ylabel('latitude')
# plt.colorbar(label='log$_{10}$(population)')
# plt.clim(3, 7)
# # Here we create a legend:
# # we'll plot empty lists with the desired size and label
# for area in [100, 300, 500]:
# plt.scatter([], [], c='k', alpha=0.3, s=area,
# label=str(area) + ' km$^2$')
# plt.legend(scatterpoints=1, frameon=False,
# labelspacing=1, title='City Area')
# plt.title('California Cities: Area and Population');

# %%
fig, ax = plt.subplots()
lines = []
styles = ['-', '--', '-.', ':']
x = np.linspace(0, 10, 1000)
for i in range(4):
    lines += ax.plot(x, np.sin(x - i * np.pi / 2),
styles[i], color='black')
ax.axis('equal')
# specify the lines and labels of the first legend
ax.legend(lines[:3], ['line A', 'line B', 'line D'],
loc='upper right', frameon=False)
# Create the second legend and add the artist manually.
from matplotlib.legend import Legend
leg = Legend(ax, lines[3:], ['line C'],
loc='lower right', frameon=False)
ax.add_artist(leg);

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])
plt.imshow(I,cmap='Blues')
plt.colorbar();
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\2299454220.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar();

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])
plt.imshow(I,cmap=plt.cm.get_cmap('Blues', 16))
plt.colorbar();
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\445813809.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar();

# %%
plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 6))
plt.colorbar()
plt.clim(-1, 1);
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\2420005992.py:2: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
# for i, axi in enumerate(ax.flat):
#     print(i,axi)
# Out:
# 0 AxesSubplot(0.125,0.536364;0.227941x0.363636)
# 1 AxesSubplot(0.398529,0.536364;0.227941x0.363636)
# 2 AxesSubplot(0.672059,0.536364;0.227941x0.363636)
# 3 AxesSubplot(0.125,0.1;0.227941x0.363636)
# 4 AxesSubplot(0.398529,0.1;0.227941x0.363636)
# 5 AxesSubplot(0.672059,0.1;0.227941x0.363636)

# %%
# ax
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
from sklearn.datasets import load_digits
digits = load_digits(n_class=6)

# %%
fig, ax = plt.subplots(8, 8, figsize=(6, 6))
for i, axi in enumerate(ax.flat):
    axi.imshow(digits.images[i], cmap='binary')
    axi.set(xticks=[], yticks=[])

# %%
from sklearn.manifold import Isomap
iso = Isomap(n_components=2)
projection = iso.fit_transform(digits.data)
# Out:
# H:\Users\severous\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_isomap.py:324: UserWarning: The number of connected components of the neighbors graph is 2 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# H:\Users\severous\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\sparse\_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
# plot the results
plt.scatter(projection[:, 0], projection[:, 1], lw=0.1,
c=digits.target, cmap=plt.cm.get_cmap('cubehelix',6))
plt.colorbar(ticks=range(6), label='digit value')
plt.clim(-0.5, 5.5)
# Out:
# C:\Users\severous\AppData\Local\Temp\ipykernel_3560\26759065.py:4: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(ticks=range(6), label='digit value')

# %%
x.size
# Out:
# 50

# %%
ax1 = plt.axes() # standard axes
ax2 = plt.axes([0.4, 0.65, 0.15, 0.15])
ax1.plot(x,np.sin(x))
ax2.plot(x[20:30],np.sin(x[20:30]))

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
ylim=(-1.2, 1.2))
x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
    fontsize=18, ha='center')

# %%
# the more flexible one
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
    fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(9, 9, sharex='col', sharey='row', figsize=(6, 6))
# figs = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i, axi in enumerate(ax.flat):
#     .subplots_adjust(hspace=0.4, wspace=0.4)
    axi.imshow(digits.images[i], cmap='binary')
    axi.set(xticks=[], yticks=[])

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
        fontsize=18, ha='center')
# fig

# %%
# Page 266

# %%
fig, ax = plt.subplots(2, 3)
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
        fontsize=18, ha='center')
# fig

# %%
grid = plt.GridSpec(3, 3, wspace=0.4, hspace=0.3)

# %%
plt.subplot(grid[:2, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, 1:])
plt.subplot(grid[2, 0:3])
# Out:
# <AxesSubplot:>

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T
# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.3, wspace=0.3)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)
# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)
# main_ax.set(xticks=[], yticks=[])
# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
orientation='vertical', color='gray')
x_hist.invert_yaxis()
y_hist.hist(y, 40, histtype='stepfilled',
orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T
# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:],yticks=[],xticks=[])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[])
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[])
# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)
# main_ax.set(xticks=[], yticks=[])
# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
orientation='vertical', color='gray')
x_hist.invert_yaxis()
y_hist.hist(y, 40, histtype='stepfilled',
orientation='horizontal', color='gray')
y_hist.invert_xaxis()
